# %%
from camseq_dataset import CamSeqDatset
import torch
import torch.utils.data as data

# %%
dataset = CamSeqDatset()

# %%
img, label = dataset.__getitem__(0)

# %%
dataloader = data.DataLoader(dataset, batch_size=4, shuffle=True)#, num_workers=4 gpu 쓸떄)

# %%
for i, (img, label) in enumerate(dataloader):
    print(img.shape)
    print(label.shape)
    break
# Out:
# torch.Size([4, 3, 144, 192])
# torch.Size([4, 1, 144, 192])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img.shape
# Out:
# torch.Size([4, 3, 144, 192])

# %%
img_check = img[0]
img_check = img_check.permute(1,2,0) #차원을 바꾸는 것 chw(텐서형-체널을 세는 방법) 에서  hwc로 바꾸는 것 (사진의 기본-넘파이축으로)
img_check = img_check.numpy()
plt.imshow(img_check)
